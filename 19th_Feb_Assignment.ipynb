# %% [markdown]
# # <Center> 19th Feb Assignment

# %% [markdown]
# # Q1:- What is Flask Framework? What are the advantages of Flask Framework?

# %% [markdown]
# Ans 1:- Flask is a Python web framework that allows for the development of web applications. Flask is a lightweight and flexible framework that provides developers with the tools they need to create web applications quickly and easily.
#
# Advantages of Flask Framework:
#
# * Lightweight: Flask is a lightweight framework and has a small core, which makes it easy to use and deploy. It does not require any particular tools or libraries, and it is easy to get started with.
#
# * Flexibility: Flask is a flexible framework that allows developers to build applications in any way they choose. It does not force a particular coding style or architecture, so developers have the freedom to use the tools and methods that work best for their projects.
#
# * Easy to learn: Flask is easy to learn and has a straightforward API. This makes it an excellent choice for beginners who want to learn how to build web applications.
#
# * Integration with other libraries: Flask can be easily integrated with other Python libraries, such as SQLAlchemy, which allows developers to create powerful and complex web applications.
#
# * Built-in development server: Flask has a built-in development server, which makes it easy to test and debug applications during development.
#
# * Extensible: Flask is highly extensible and allows developers to add new features and functionality easily. There are many extensions available that can be added to the framework to extend its capabilities.
#
# * Large community: Flask has a large community of developers who contribute to the framework and provide support and documentation. This makes it easy to find answers to questions and to get help when needed.

# %% [markdown]
# # Q2:- Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %%
# Ans 2:-

from flask import Flask

app = Flask(__name__)

@app.route("/")
def helloworld():
    return "Hello World!!!"


if (__name__) == "__main__":
   app.run(host = "0.0.0.0")

# %% [markdown]
# ![Hello Word.JPG](attachment:08d1c217-c941-4ba1-97e8-7f1be74bfbf5.JPG)

# %% [markdown]
# # Q3:- What is App routing in Flask? Why do we use app routes?

# %% [markdown]
# Ans 3:- In Flask, App routing refers to the process of defining the mapping between the URLs and the functions that handle the requests made to those URLs.
#
# When a user makes a request to a Flask web application, the URL of the requested page is used to determine which function should handle the request. This is achieved by defining app routes in Flask. An app route is a decorator that associates a URL with a function in the application.
#
# We use app routes in Flask to create a clean and organized URL structure for our web application. By defining app routes, we can create logical URLs that are easy for users to remember and navigate. Additionally, app routes allow us to map specific URLs to specific functions in our application, making it easier to manage and maintain our codebase.

# %% [markdown]
# # Q4:- Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
# Company Name: ABC Corporation
#
# Location: India
#
# Contact Detail: 999-999-9999

# %%
# Ans 4:- 

from flask import Flask

app = Flask(__name__)

@app.route("/")
def com_details():
    return '<h2>Company Name: ABC Corporation</h2><br><h2>Location: India</h2><br><h2>Contact Detail: 999-999-9999</h2>'

@app.route('/welcome')
def welcome():
    return '<h1> Welcome to ABC Corporation </h1>'


if (__name__) == "__main__":
   app.run(host = "0.0.0.0")

# %% [markdown]
# ![image.png](attachment:fa2a7975-40fd-4d7d-ba11-dfa35221cc24.png)

# %% [markdown]
# ![image.png](attachment:4221469b-321d-48a4-8486-8eab97c8ba41.png)

# %% [markdown]
# # Q5:- What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %% [markdown]
# Ans 5:- In Flask, the url_for() function is used for URL building. This function takes the endpoint name and any arguments and returns a URL to that endpoint. The url_for() function is useful because it generates URLs based on the routes defined in the application, which ensures that the URLs are consistent and will continue to work even if the URL scheme changes.

# %%
from flask import Flask, url_for

app = Flask(__name__)

@app.route('/')
def index():
    return 'This is the homepage.'

@app.route('/user/<username>')
def profile(username):
    return f'This is the profile page for {username}.'

@app.route('/login')
def login():
    return 'Please log in.'

with app.test_request_context():
    print(url_for('index'))  # output: '/'
    print(url_for('login'))  # output: '/login'
    print(url_for('login', next='/'))  # output: '/login?next=%2F'
    print(url_for('profile', username='Atul'))  # output: '/user/Atul'

# %% [markdown]
# # <center> End of Assignment
